# %%
import pandas as pd
import seaborn as sns

# %%
# sns.set(rc={'figure.figsize':(11,8.5)})

# %%
LILA_COYOTE_IMAGES_URLS_AND_LABELS = 'data/lila_coyote_image_urls_and_labels.csv'

# %%
df = pd.read_csv(LILA_COYOTE_IMAGES_URLS_AND_LABELS)
df = df.dropna(axis=1, how='all')
df
# Out:
#                dataset_name  \
# 0      Caltech Camera Traps
# 1      Caltech Camera Traps
# 2      Caltech Camera Traps
# 3      Caltech Camera Traps
# 4      Caltech Camera Traps
# ...                     ...
# 40335    Idaho Camera Traps
# 40336    Idaho Camera Traps
# 40337    Idaho Camera Traps
# 40338    Idaho Camera Traps
# 40339    Idaho Camera Traps
#
#                                                      url  \
# 0      https://lilablobssc.blob.core.windows.net/calt...
# 1      https://lilablobssc.blob.core.windows.net/calt...
# 2      https://lilablobssc.blob.core.windows.net/calt...
# 3      https://lilablobssc.blob.core.windows.net/calt...
# 4      https://lilablobssc.blob.core.windows.net/calt...
# ...                                                  ...
# 40335  https://lilablobssc.blob.core.windows.net/idah...
# 40336  https://lilablobssc.blob.core.windows.net/idah...
# 40337  https://lilablobssc.blob.core.windows.net/idah...
# ...

# %%
df.columns
# Out:
# Index(['dataset_name', 'url', 'image_id', 'sequence_id', 'location_id',
#        'frame_num', 'original_label', 'scientific_name', 'common_name',
#        'datetime', 'annotation_level', 'kingdom', 'phylum', 'subphylum',
#        'class', 'subclass', 'infraclass', 'superorder', 'order', 'family',
#        'genus', 'species'],
#       dtype='object')

# %%
ax = sns.countplot(df, x="dataset_name")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
ax
# Out:
# <AxesSubplot: xlabel='dataset_name', ylabel='count'>

# %%
df['location_id'].unique().shape
# Out:
# (230,)

# %%
df['annotation_level'].value_counts()
# Out:
# unknown     20968
# image       16684
# sequence     2688
# Name: annotation_level, dtype: int64

# %%
df['datetime'] = df['datetime'].astype('datetime64[ns]')

df['year'] = df['datetime'].dt.year
df['month'] = df['datetime'].dt.month
df['hour'] = df['datetime'].dt.hour

df['day'] = df['datetime'].dt.day
df['minute'] = df['datetime'].dt.minute
df['second'] = df['datetime'].dt.second
df['datetime'].count()
# Out:
# 19038

# %%
sns.displot(df, x="year", hue="dataset_name")

# %%
sns.displot(df, x="month", hue="dataset_name")

# %%
sns.displot(df, x="hour", hue="dataset_name")
